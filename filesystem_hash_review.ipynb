# %% [markdown]
# Designed to analyze the output of system_file_scan.py
# 2 May 25 ldh
# v0.1

# %%
import os, pickle, pandas as pd

# %%
# !ls -alt

# %%
with open('all_subs_1May25.out', 'rb') as ifile:
    xxx = pickle.load(ifile)

# %%
with open('pkl_storage.out', 'rb') as ifile:
    yyy = pickle.load(ifile)

# %%
xxx.info()
yyy.info()

# %%
xxx.md5_hash.value_counts().head(20)

# %%
yyy.md5_hash.value_counts().head(20)

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 1000)

# %%
xxx[xxx.md5_hash == '7e2e233a1c911a6e9f7fc1c2a955103b']['filename_full_path'].count()

# %%
xxx[xxx.md5_hash == '7e2e233a1c911a6e9f7fc1c2a955103b']['filename_full_path']

# %%
xxx[xxx.md5_hash == '7e2e233a1c911a6e9f7fc1c2a955103b']

# %%
xxx[xxx.md5_hash == '7e2e233a1c911a6e9f7fc1c2a955103b']['stat'].values[0]

# %%
date_list1 = []
for x in xxx[xxx.md5_hash == '7e2e233a1c911a6e9f7fc1c2a955103b']['stat']:
    y = x.find('Birth')
    z = x[y+9:y+17]
    date_list1.append(z)
date_list1.sort()
print(date_list1)

# %%
target1 = xxx[xxx.md5_hash == '7e2e233a1c911a6e9f7fc1c2a955103b']['filename_full_path']
len(target1)

# %%
target1.to_csv('BexarMis_240714to240814.csv', index = False, header = False)
