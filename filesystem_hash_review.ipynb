# %% [markdown]
# Designed to analyze the output of system_file_scan.py
# 2 May 25 ldh
# v0.1

# %%
import os, pickle, pandas as pd

# %%
# !ls -alt
# Out:
# total 148
# drwxrwxr-x  2 ldhagen ldhagen   4096 May 18 14:27 .ipynb_checkpoints
# drwxrwxr-x  4 ldhagen ldhagen   4096 May 18 14:27 .
# -rw-rw-r--  1 ldhagen ldhagen 111701 May 18 14:21 photos_test1.pkl
# drwxrwxr-x  8 ldhagen ldhagen   4096 May 18 14:11 .git
# -rw-rw-r--  1 ldhagen ldhagen   1751 May 18 14:09 README.md
# -rw-rw-r--  1 ldhagen ldhagen   3362 May 18 14:08 walk_id.py
# -rw-rw-r--  1 ldhagen ldhagen   2640 May 18 14:08 system_file_scan.py
# -rw-rw-r--  1 ldhagen ldhagen   6047 May 18 13:53 filesystem_hash_review.ipynb
# drwxrwxr-x 15 ldhagen ldhagen   4096 May 18 13:53 ..

# %%
with open('photos_test1.pkl', 'rb') as ifile:
    xxx = pickle.load(ifile)

# %%
xxx.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename_full_path  650 non-null    str
#  1   md5_hash            650 non-null    str
#  2   size                650 non-null    int64
#  3   mtime               650 non-null    float64
#  4   ctime               650 non-null    float64
#  5   mode                650 non-null    int64
# dtypes: float64(2), int64(2), str(2)
# memory usage: 30.6 KB

# %%
xxx.md5_hash.value_counts().head(20)
# Out:
# md5_hash
# d41d8cd98f00b204e9800998ecf8427e    3
# 36482f38261375b1f99bff80a4bbf69a    1
# aaeb0e5a8aed08feec6e41b132e0fc49    1
# 9691f908aa9fbbb616086f7142b5f8fd    1
# 52ebddef2fea7b6731f6caf4f54d37cc    1
# 3938ea31aaa63eb45916301b06516e69    1
# 7e1078dd4e26ea7a55ebb6c3a82e577f    1
# 68204588dd300d396fc18ba3d9b47271    1
# 52bb781e4e26930139e78f1f33088ebe    1
# 27d0eb1cee201020d66b7703012e370d    1
# 7ffebaa9ab6c107cd2ae2e6f65d09af5    1
# 6f74eb92483ed0e1577e6ddd226bfde0    1
# 07332685b6241fb95bf7ba2b152e64e7    1
# 320854e5ab302db5800c77d5fcda12d7    1
# 05d5a362e13f25c0e9203df677f94408    1
# 2e8d462833ae6bc332706e6b2c62f5fa    1
# cd08c2d02304be1404a38b1f642b1895    1
# cf04e4b116830db5d5b3808f80dcbccf    1
# 8af43a4ce05f252e817122fd8232476e    1
# a56d332945176f28d217ee22820bbb86    1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 1000)

# %%
xxx[xxx.md5_hash == 'd41d8cd98f00b204e9800998ecf8427e']['filename_full_path'].count()
# Out:
# np.int64(3)

# %%
xxx[xxx.md5_hash == '8244c4cc8508425b6612fa24df71e603']['filename_full_path']
# Out:
# Series([], Name: filename_full_path, dtype: str)

# %%
date_list1 = []
for x in xxx[xxx.md5_hash == 'd5a67a75a19956592e3910aa00001dbd']['stat']:
    y = x.find('Birth')
    z = x[y+9:y+17]
    date_list1.append(z)
date_list1.sort()
print(date_list1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /var/tmp/ldh/virt1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 date_list1 = []
# ----> 2 for x in xxx[xxx.md5_hash == 'd5a67a75a19956592e3910aa00001dbd']['stat']:
#       3     y = x.find('Birth')
#       4     z = x[y+9:y+17]
#
# File /var/tmp/ldh/virt1/lib/python3.12/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File /var/tmp/ldh/virt1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'stat'

# %%
target1 = xxx[xxx.md5_hash == 'd5a67a75a19956592e3910aa00001dbd']['filename_full_path']
len(target1)
# Out:
# 0

# %%
target1.to_csv('TexasWarn240720_240819.csv', index = False, header = False)

# %%
! cat TexasWarn240720_240819.csv

# %%
! cp /var/tmp/ldh/Texas_Warn_storage/Texas_Warn_23_Jul_24_09_00_58 TexasWarn240720_240819.pkl
# Out:
# cp: cannot stat '/var/tmp/ldh/Texas_Warn_storage/Texas_Warn_23_Jul_24_09_00_58': No such file or directory

# %%
# !md5sum TexasWarn240720_240819.pkl

# %%
with open('/var/tmp/ldh/Texas_Warn_storage/Texas_Warn_20_Jul_24_09_00_30', 'rb') as ifile:
    zzz = pickle.load(ifile)

# %%
zzz.head()

# %%
zzz.info()

# %%
! df -k .

# %%
xxx[xxx.md5_hash == '986f5bd350f8f4f439ff3659d715f4c1']['stat']

# %%
size_list1 = []
for x in xxx.head(1220)['stat']:
    y = x.find('Size')
    z = x[y+6:y+15]
    size_list1.append(int(z))
size_list1.sort(reverse = True)
print(size_list1)
